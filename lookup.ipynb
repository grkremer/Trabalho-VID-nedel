# %%
import pandas as pd
import numpy as np
import seaborn as sns

import requests
import json
import geopy

import time
import parquet

# %%
data = pd.read_parquet('Dados_processados_COMPLETO.parquet')

# %%
data.head(30)
# Out:
#     index  DATA PGTO    CPF SERVIDOR CPF/CNPJ FORNECEDOR  \
# 0   96625 2018-01-01  ***.118.204-**      37064730000166
# 1   96626 2018-02-01  ***.024.754-**      00394502017209
# 2   96627 2018-02-01  ***.002.851-**      03696869000100
# 3   96628 2018-02-01  ***.002.851-**      38030169000167
# 4   96629 2018-02-01  ***.002.851-**      47508411103559
# 5   96630 2018-02-01  ***.002.851-**      27501464000138
# 6   96631 2018-02-01  ***.002.851-**      47508411094975
# 7   96632 2018-02-01  ***.002.851-**      00672600000104
# 8   96633 2018-02-01  ***.002.851-**      03696869000100
# 9   96634 2018-02-01  ***.002.851-**      45543915019796
# 10  96635 2018-02-01  ***.002.851-**      14653915000100
# 11  96636 2018-03-01  ***.118.204-**      19604516000173
# 12  96637 2018-03-01  ***.118.204-**      00672600000104
# 13  96638 2018-03-01  ***.118.204-**      38030169000167
# 14  96639 2018-03-01  ***.118.204-**      47508411103559
# ...

# %%
from geopy.geocoders import GoogleV3

geo_locator = GoogleV3(api_key='AIzaSyA7HD-DcYO0LndUfrEvhGe8LlOqXvBqO3A')
print(data['ENDEREÇO'].iloc[1].replace('S/N, ', ''))
print(geo_locator.geocode('ESTRADA CHAPEU DO SOL,1035'))
i = 0
for i in range(1,5):
    try:
        location = geo_locator.geocode(data['ENDEREÇO'].iloc[i].replace('S/N, ', ''), exactly_one=True)
        print(location.latitude, location.longitude)
    except:
        print(data['ENDEREÇO'].iloc[i])
    i = i+1
def getLatLong(endereço):
    try:
        location = geo_locator.geocode(endereço.replace('S/N, ', ''), exactly_one=True)
        return location.latitude, location.longitude
    except:
        return None, None
# Out:
# AV RAFAEL LEVY MIRANDA, MANGARATIBA, RJ
# Estr. Chapéu do Sol, 1035 - Belém Novo, Porto Alegre - RS, 91787-030, Brazil
# -22.9298966 -43.908423
# -15.7592875 -47.8847321
# -15.7508444 -47.8845961
# -15.7592875 -47.8847321

# %%
data['Latitude'] = ''
data['Longitude'] = ''

 
#data['Latitude'] = data['ENDEREÇO'].apply(lambda x: getLatLong(x))
for row in range(len(data)):
    data['Latitude'].iloc[row], data['Longitude'].iloc[row] = getLatLong(data['ENDEREÇO'].iloc[row])
# Out:
# C:\Users\gusta\AppData\Local\Temp\ipykernel_14328\2913389910.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Latitude'].iloc[row], data['Longitude'].iloc[row] = getLatLong(data['ENDEREÇO'].iloc[row])

# %%
data
# Out:
#         index  DATA PGTO    CPF SERVIDOR CPF/CNPJ FORNECEDOR  \
# 0       96625 2018-01-01  ***.118.204-**      37064730000166
# 1       96626 2018-02-01  ***.024.754-**      00394502017209
# 2       96627 2018-02-01  ***.002.851-**      03696869000100
# 3       96628 2018-02-01  ***.002.851-**      38030169000167
# 4       96629 2018-02-01  ***.002.851-**      47508411103559
# ...       ...        ...             ...                 ...
# 16710  113335 2022-03-12  ***.136.591-**      17261661005728
# 16711  113336 2022-03-12  ***.136.591-**      39879944000116
# 16712  113337 2022-04-12  ***.136.591-**      47508411094975
# 16713  113338 2022-04-12  ***.136.591-**      12550441000146
# 16714  113339 2022-04-12  ***.136.591-**      03696869000100
#
#                                          NOME FORNECEDOR          VALOR TIPO  \
# 0                                             5 ESTRELAS      R$ 20,87     C
# ...

# %%
data.to_excel('Dados_processados_COMPLETO.xlsx')

# %%
data.to_parquet('Dados_processados_COMPLETO.parquet')

# %%
data.sample(10)
data[['DATA PGTO', 'CPF/CNPJ FORNECEDOR', 'NOME FORNECEDOR', 'VALOR', 'SUBELEMENTO DE DESPESA', 'ATIVIDADE_PRINCIPAL', 'MATRIZ', 'NATUREZA_JURIDICA', 'MUNICIPIO', 'UF','ENDEREÇO','Latitude', 'Longitude']].head(10)
# Out:
#    DATA PGTO CPF/CNPJ FORNECEDOR  \
# 0 2018-01-01      37064730000166
# 1 2018-02-01      00394502017209
# 2 2018-02-01      03696869000100
# 3 2018-02-01      38030169000167
# 4 2018-02-01      47508411103559
# 5 2018-02-01      27501464000138
# 6 2018-02-01      47508411094975
# 7 2018-02-01      00672600000104
# 8 2018-02-01      03696869000100
# 9 2018-02-01      45543915019796
#
#                                      NOME FORNECEDOR          VALOR  \
# 0                                         5 ESTRELAS      R$ 20,87
# 1        CENTRO DE ADESTRAMENTO DA MARAMBAIA (CADIM)   R$ 5.220,00
# 2              BIG TRANS COMERCIAL DE ALIMENTOS LTDA     R$ 545,06
# 3                      SUPERMERCADO VAREJAO OBA LTDA     R$ 204,19
# 4  COMPANHIA BRASILEIRA DE DISTRIBUIÇÃO PÃO DE AÇ...     R$ 203,20
# 5                                         JHS CARNES     R$ 936,81
# 6               COMPANHIA BRASILEIRA DE DISTRIBUIÇÃO     R$ 505,89
# ...
